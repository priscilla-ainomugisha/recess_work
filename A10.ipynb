# %%
#Day 8
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df4= pd.read_csv('bse_dataset4.csv')
df4
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5                    NaN         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
# confirming data shape
df4.shape
# Out:
# (169, 15)

# %%
#Checking for the columns
df4.columns
# Out:
# Index(['Timestamp', 'gender', 'Age', 'emotion', 'YOB', 'CGPA',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? ', 'Duration',
#        'Pulse', 'Maxpulse', 'Calories'],
#       dtype='object')

# %%
# PREPROCESSING
df4_new = df4.dropna()
df4_new
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# 13   05/07/2023 09:39:40           MALE  22.0                  fine
# ...

# %%
df4.fillna(value=100, inplace=True)#The inplace=True means that the new dataset will remove all the null values 
df4
# Out:
#                Timestamp         gender    Age               emotion  \
# 0    05/07/2023 09:38:39           Male   21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock   45.0                 Weird
# 2    05/07/2023 09:39:09        Female    20.0                 Happy
# 3    05/07/2023 09:39:12           Male   21.0                 Happy
# 4    05/07/2023 09:39:14         Female   21.0                 Happy
# 5                    100         Female   23.0                Happy
# 6    05/07/2023 09:39:21         female   21.0            irritated
# 7    05/07/2023 09:39:23        Female    22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male   22.0                   Sad
# 9    05/07/2023 09:39:27         Female   20.0                 happy
# 10            2023/12/26           Male   24.0                 Happy
# 11   05/07/2023 09:39:27         Female   20.0                 happy
# 12   05/07/2023 09:39:38           Male   25.0                 Happy
# ...

# %%
df4['Calories'].fillna(value=100,inplace=True)#The inplace=True means that the new dataset will remove all the null values 
df4
# Out:
#                Timestamp         gender    Age               emotion  \
# 0    05/07/2023 09:38:39           Male   21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock   45.0                 Weird
# 2    05/07/2023 09:39:09        Female    20.0                 Happy
# 3    05/07/2023 09:39:12           Male   21.0                 Happy
# 4    05/07/2023 09:39:14         Female   21.0                 Happy
# 5                    100         Female   23.0                Happy
# 6    05/07/2023 09:39:21         female   21.0            irritated
# 7    05/07/2023 09:39:23        Female    22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male   22.0                   Sad
# 9    05/07/2023 09:39:27         Female   20.0                 happy
# 10            2023/12/26           Male   24.0                 Happy
# 11   05/07/2023 09:39:27         Female   20.0                 happy
# 12   05/07/2023 09:39:38           Male   25.0                 Happy
# ...

# %%
print(df4.to_string())
# Out:
#                Timestamp         gender    Age               emotion            YOB              CGPA Do you have a Girl Friend or BOY Friend Do you have Depression? Do you have Anxiety? Do you have Panic attack? Did you have seek any specialist for a treatment?   Duration  Pulse  Maxpulse  Calories
# 0    05/07/2023 09:38:39           Male   21.0               Content           2002              4.22                                      No                      No                  Yes                       Yes                                                Yes        60    110       130     409.1
# 1    05/07/2023 09:38:57  Marabou stock   45.0                 Weird           2100               8.9                                     Yes                     Yes                  Yes                       Yes                                                 No        60    117       145     479.0
# ...

# %%
# Replace using mean , Median, Mode
# Calculate mean 
m = df4['Age'].mean()
df4['Age'].fillna(m, inplace=True)
m
# Out:
# 23.414201183431953

# %%
print(df4.to_string())
# Out:
#                Timestamp         gender    Age               emotion            YOB              CGPA Do you have a Girl Friend or BOY Friend Do you have Depression? Do you have Anxiety? Do you have Panic attack? Did you have seek any specialist for a treatment?   Duration  Pulse  Maxpulse  Calories
# 0    05/07/2023 09:38:39           Male   21.0               Content           2002              4.22                                      No                      No                  Yes                       Yes                                                Yes        60    110       130     409.1
# 1    05/07/2023 09:38:57  Marabou stock   45.0                 Weird           2100               8.9                                     Yes                     Yes                  Yes                       Yes                                                 No        60    117       145     479.0
# ...

# %%
# Shows Display of all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Empty cells, wrong formats, wrong data, duplicate(Core of data Preparation and Preprocessing)
# Calculate Median
med =df4['Calories'].median()
df4['Calories'].fillna(med, inplace = True)
print(med)
# Out:
# 310.2

# %%
df4
# Out:
#                Timestamp         gender    Age               emotion  \
# 0    05/07/2023 09:38:39           Male   21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock   45.0                 Weird
# 2    05/07/2023 09:39:09        Female    20.0                 Happy
# 3    05/07/2023 09:39:12           Male   21.0                 Happy
# 4    05/07/2023 09:39:14         Female   21.0                 Happy
# 5                    100         Female   23.0                Happy
# 6    05/07/2023 09:39:21         female   21.0            irritated
# 7    05/07/2023 09:39:23        Female    22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male   22.0                   Sad
# 9    05/07/2023 09:39:27         Female   20.0                 happy
# 10            2023/12/26           Male   24.0                 Happy
# 11   05/07/2023 09:39:27         Female   20.0                 happy
# 12   05/07/2023 09:39:38           Male   25.0                 Happy
# ...

# %%
# Exercise 1
# Calculate mode on age 
mode_value = df4['Age'].mode()
print("Mode:", mode_value)
# Out:
# Mode: 0    21.0
# Name: Age, dtype: float64

# %%
#To resaerch
# *Interpolation

# %%
# WRONG FORMAT
# Wrong Formats Row that is hard to analyze(NaN,)
#NaN Row 5 contained Nan values and we filled with
df4['Timestamp'].fillna("05/07/2023 09:45:13", inplace=True)
df4
# Out:
#                Timestamp         gender    Age               emotion  \
# 0    05/07/2023 09:38:39           Male   21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock   45.0                 Weird
# 2    05/07/2023 09:39:09        Female    20.0                 Happy
# 3    05/07/2023 09:39:12           Male   21.0                 Happy
# 4    05/07/2023 09:39:14         Female   21.0                 Happy
# 5                    100         Female   23.0                Happy
# 6    05/07/2023 09:39:21         female   21.0            irritated
# 7    05/07/2023 09:39:23        Female    22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male   22.0                   Sad
# 9    05/07/2023 09:39:27         Female   20.0                 happy
# 10            2023/12/26           Male   24.0                 Happy
# 11   05/07/2023 09:39:27         Female   20.0                 happy
# 12   05/07/2023 09:39:38           Male   25.0                 Happy
# ...

# %%
# Replacing at a specific place
df4.at[5,'Timestamp']='05/07/2023 09:45:13'
df4
# Out:
#                Timestamp         gender    Age               emotion  \
# 0    05/07/2023 09:38:39           Male   21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock   45.0                 Weird
# 2    05/07/2023 09:39:09        Female    20.0                 Happy
# 3    05/07/2023 09:39:12           Male   21.0                 Happy
# 4    05/07/2023 09:39:14         Female   21.0                 Happy
# 5    05/07/2023 09:45:13         Female   23.0                Happy
# 6    05/07/2023 09:39:21         female   21.0            irritated
# 7    05/07/2023 09:39:23        Female    22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male   22.0                   Sad
# 9    05/07/2023 09:39:27         Female   20.0                 happy
# 10            2023/12/26           Male   24.0                 Happy
# 11   05/07/2023 09:39:27         Female   20.0                 happy
# 12   05/07/2023 09:39:38           Male   25.0                 Happy
# ...

# %%
# Wrong Data
for x in df4.index:
    if df4.loc[x,'gender'] == "Marabou stock":
        df4.drop(x,inplace=True)
df4
# Out:
#                Timestamp   gender    Age               emotion            YOB  \
# 0    05/07/2023 09:38:39     Male   21.0               Content           2002
# 2    05/07/2023 09:39:09  Female    20.0                 Happy           2002
# 3    05/07/2023 09:39:12     Male   21.0                 Happy           2003
# 4    05/07/2023 09:39:14   Female   21.0                 Happy           2002
# 5    05/07/2023 09:45:13   Female   23.0                Happy            2000
# 6    05/07/2023 09:39:21   female   21.0            irritated            2001
# 7    05/07/2023 09:39:23  Female    22.0  In a state of wonder           2001
# 8    05/07/2023 09:39:26     Male   22.0                   Sad           2001
# 9    05/07/2023 09:39:27   Female   20.0                 happy           2002
# 10            2023/12/26     Male   24.0                 Happy           1998
# 11   05/07/2023 09:39:27   Female   20.0                 happy           2002
# ...

# %%
# Checking for dupliates
print(df4.duplicated())
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# ...

# %%
df4.drop_duplicates(inplace=True)

# %%
print(df4.duplicated())
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# 67     False
# ...

# %%
# Data Visualization Plotting matplot lib (Heatmap, Piechart, barplot, line plot(dotted/dashed) scatterplot library, hostogram)
df4['Age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
