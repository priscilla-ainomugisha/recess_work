# %%
# Intrduction to machine Learnings
# Algorithms, models that help computer to learn and Predict
# Applications of Machine learning 
"""_summary_
1.Image Processing
2. Speech recognition
3.Fraud detection

Approaches to machine Learning
1. Supervised learning-dataset is labelled,predict,linear regression,
decision tree, support vector machines,neural networks [supervised learning 
algorithms]
2. unsupervised learning:deals with nlabeled data, clustering algorithms to 
group data together. k-means clustering, hierachical clustering,PCA(Principal Component Analysis)


#First step is -Problem Formulation
# Define the Problem! Classification task, regression Analysis,clustering, anomaly detection recommendation
2.gather the data
2.split the data

Dta types
1.numerical data .can be discrete(integers )or continous values
2. Categorical data -can be measured against each other
3. Ordinal data can be measured against each other
"""
# Out:
# '_summary_\n1.Image Processing\n2. Speech recognition\n3.Fraud detection\n\nApproaches to machine Learning\n1. Supervised learning-dataset is labelled,predict,linear regression,\ndecision tree, support vector machines,neural networks [supervised learning \nalgorithms]\n2. unsupervised learning:deals with nlabeled data, clustering algorithms to \ngroup data together. k-means clustering, hierachical clustering,PCA(Principal Component Analysis)\n\n\n#First step is -Problem Formulation\n# Define the Problem! Classification task, regression Analysis,clustering, anomaly detection recommendation\n2.gather the data\n2.split the data\n\nDta types\n1.numerical data .can be discrete(integers )or continous values\n2. Categorical data -can be measured against each other\n3. Ordinal data can be measured against each other\n'

# %%
import numpy as np #linear algebra
import pandas as pd #data processing
import matplotlib.pyplot as plt #plottin/data visualization
import seaborn as sns #satatistical data visualization
# %matplotlib inline 

#ML for regression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Control Display
pd.option.display.max_columns = 50
sns.set(style='darkgrid',rc={'axes.facecolor':'#fff',})

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 12
#       9 from sklearn.model_selection import train_test_split
#      11 # Control Display
# ---> 12 pd.option.display.max_columns = 50
#      13 sns.set(style='darkgrid',rc={'axes.facecolor':'#fff',})
#      15 # Ignore warnings
#
# AttributeError: module 'pandas' has no attribute 'option'

# %%
# read dataset
df = pd.read_csv('heart_disease.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
"""
cp-chest pain
trestbps=resting blood pressure
cho-cholestrol
fbs-fasting blood sugar
restceg = resting electrocardiography
exang -exercise induced agina
oldpeak - ST depression induced
slope- slope of the peak exercise
ca- number of major vessels
thal-normal cases, fixed defect, reversable defect
target-have diseases or not
"""

# %%
# show number of people with hear diseases
#column target
df.target.value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
#show percentage of male and female
count_female = len(df[df.sex ==0])
count_male = len(df[df.sex ==1])

#show ouput
print('percentage of female patints:{:.2f}%'.format(count_female/(len(df.sex))*100))
print('percentage of female patints:{:.2f}%'.format(count_male/(len(df.sex))*100))
# Out:
# percentage of female patints:30.44%
# percentage of female patints:69.56%

# %%
df.groupby('target').mean()
# Out:
#               age       sex        cp    trestbps        chol       fbs  \
# target
# 0       56.569138  0.827655  0.482966  134.106212  251.292585  0.164329
# 1       52.408745  0.570342  1.378327  129.245247  240.979087  0.134981
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.456914  139.130261  0.549098  1.600200  1.166333  1.158317  2.539078
# 1       0.598859  158.585551  0.134981  0.569962  1.593156  0.370722  2.119772

# %%
# Bar plot showing heart disease frequency of age
pd.crosstab(df.age,df.target).plot(kind='bar',figsize =(20,6))
plt.title('Heart Disease Frequency for ages')
plt.xlabel('age')
plt.ylabel('Frequency')
plt.show()

# %%
pd.crosstab(df.sex,df.target).plot(kind='bar',figsize =(20,6), color=['#64B6AC','#F70'])
plt.title('Heart Disease Frequency for Sex')
plt.xlabel('Sex(0=Female, 1=Male)')
plt.ylabel('Frequency')
plt.xticks
plt.show()

# %%
age = df['age']
chol = df['chol']

# Create scatter plot
plt.scatter(age, chol, c=df['target'], cmap='coolwarm')
plt.xlabel('Age')
plt.ylabel('Cholesterol')
plt.title('Scatter Plot: Age vs Cholesterol')
plt.colorbar(label='Target')
plt.show()

# %%
#Working with ML model Accuracy of Different ML Models
# create model for Logistic Regression
# solve problem based on classification. Create independent 
#variables and dependent variables
# categorical prediction

# %%
# creating a model for logistic regression
y = df.target.values
x_data =df.drop(['target'],axis =1)

# %%
# Normalize the data ! split data for training and testing
# 80% for training and 20% for testing
# Normalize the data X=(X-Xmin)/(Xmax-Xmin)
x =(x_data - np.min(x_data)) /(np.max(x_data))-(np.min(x_data))

# %%
# Slice the data 80% training and 20% testing

# %%
# transpose matrices
x_train =x_train.T
y_train =y_train.T
x_test =x_test.T
y_test =y_test.T
